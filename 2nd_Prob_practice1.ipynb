# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 세팅
plt.style.use(['dark_background'])

# %%
df = pd.read_csv('./data/StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
x72 = df[df['math score'] == 72]
x72
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 83     male        group E          associate's degree      standard
# 126    male        group B            some high school      standard
# 170    male        group A                 high school      standard
# 226  female        group C                some college      standard
# 345  female        group C                 high school      standard
# 459    male        group B                 high school      standard
# 467    male        group A                 high school  free/reduced
# 547    male        group C                 high school      standard
# 642  female        group B            some high school  free/reduced
# 745    male        group D          associate's degree      standard
# 778  female        group A                some college      standard
# 786  female        group E            some high school  free/reduced
# ...

# %%
x72over = df[df['math score'] > 72]
x72over
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 6    female        group B                some college      standard
# 13     male        group A                some college      standard
# 16     male        group C                 high school      standard
# ..      ...            ...                         ...           ...
# 984  female        group C            some high school      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Ratio of male, who's math score over 72

# %%
male = df[df['gender'] == 'male' ]
male
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
p_male = len(male) / len(df)
p_male
# Out:
# 0.482

# %%
male72more = male[male['math score'] >= 72]
male72more
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 4     male        group C                some college      standard
# 13    male        group A                some college      standard
# 16    male        group C                 high school      standard
# 24    male        group D           bachelor's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# ..     ...            ...                         ...           ...
# 971   male        group C            some high school      standard
# 981   male        group D            some high school      standard
# 982   male        group B            some high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 4                      none          76             78             75
# ...

# %%
p_male72more = len(male72more) / len(df)
p_male72more
# Out:
# 0.208

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
plt.hist(df['math score'])
plt.show()

# %%
plt.hist(df['math score'], bins = 100)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12616/938047583.py in <module>
#       9 plt.legend()
#      10 plt.grid(False) # grid를 없앴습니다.
# ---> 11 plt.savefig('../../assets/images/markdown_img/180627_plt_style_use_dark_background.svg')
#      12 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3013                 patch.set_edgecolor('none')
#    3014
# -> 3015         self.canvas.print_figure(fname, **kwargs)
#    3016
# ...
