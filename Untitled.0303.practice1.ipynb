# %% [markdown]
# # Import Library

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
print(pd.__version__)
print(sns.__version__)
# Out:
# 1.3.5
# 0.11.2

# %%
df = sns.load_dataset("mpg")
df.shape
# Out:
# (398, 9)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.isnull()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model_year  origin   name
# 0         False   False  False
# 1         False   False  False
# ...

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# mpg             0.000000
# cylinders       0.000000
# displacement    0.000000
# horsepower      0.015075
# weight          0.000000
# acceleration    0.000000
# model_year      0.000000
# origin          0.000000
# name            0.000000
# dtype: float64

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.describe(include='object')
# Out:
#        origin        name
# count     398         398
# unique      3         305
# top       usa  ford pinto
# freq      249           6

# %%
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            305
# dtype: int64

# %%
df['mpg'].unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 24. , 22. , 21. , 27. , 26. , 25. ,
#        10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. , 35. ,
#        20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5,
#        26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1,
#        32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1,
#        17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2,
#        19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2,
#        34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4,
#        24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3,
#        43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8,
#        23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9,
#        31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %% [markdown]
# ##  전체 수치변수에 대한 히스토그램 그리기
# ### 히스토그램 : 빈도수를 수치화한것
# ### 히스토그램 사용 이유 : 빈도수를 파악하기 위함!

# %%
df.hist(figsize=(15,15), bins = 100)
plt.show()

# %% [markdown]
# ## skew 를 통해 전체 수치 변수에 대한 왜도(비대칭도) 구하기

# %%
### 비대칭도(왜도)
* 실수 값 확률 변수의 확률 분포 비대칭성을 나타내는 지표
* 왜도의 값은 양수나 음수가 될 수 있으며 정의되지 않을 수도 있음
* 왜도가 음수일 경우에는 확률밀도함수의 왼쪽 부분에 긴 꼬리를 가지며 중앙값을 포함한 자료가 오른쪽에 더 많이 분포
* 왜도가 양수일 때는 확률밀도함수의 오른쪽 부분에 긴 꼬리를 가지며 자료가 왼쪽에 더 많이 분포
* 평균과 중앙값이 같으면 왜도는 0

<img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Negative_and_positive_skew_diagrams_%28English%29.svg/700px-Negative_and_positive_skew_diagrams_%28English%29.svg.png" width="300">

출처 : https://ko.wikipedia.org/wiki/%EB%B9%84%EB%8C%80%EC%B9%AD%EB%8F%84
# Out:
#   File "C:\Users\mayo9\AppData\Local\Temp\ipykernel_3492\965309512.py", line 2
#     * 실수 값 확률 변수의 확률 분포 비대칭성을 나타내는 지표
#          ^
# SyntaxError: invalid syntax

# %%
df.skew()

# 아래 빨간 메시지는 원인 메시지! 에러(오류)는 안나오고, 원인에 대한 내용만 나옴!
# Out:
# C:\ProgramData\Anaconda3\envs\goddol\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# mpg             0.457066
# cylinders       0.526922
# displacement    0.719645
# horsepower      1.087326
# weight          0.531063
# acceleration    0.278777
# model_year      0.011535
# dtype: float64

# %%
df.kurt()
# Out:
# C:\ProgramData\Anaconda3\envs\goddol\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# mpg            -0.510781
# cylinders      -1.376662
# displacement   -0.746597
# horsepower      0.696947
# weight         -0.785529
# acceleration    0.419497
# model_year     -1.181232
# dtype: float64

# %%
df['mpg']
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
sns.displot(data=df,x='mpg')
# displot 종류의 기본값은  hist임! 아래 코드와 같음
# sns.displot(data=df,x='mpg', kind='hist')
# 위의 코드에서 shift + tab 클릭하면 정보가 나옴!

# %%
# kde -> 옵선, hist 그래프로 그린 것!
# 기본값이 hist 이고, kde가 옵션인데, kde로 지정해서 그릴 수 있음! 

sns.displot(data=df,x='mpg',kind = 'kde')

# %%
sns.displot(data=df,x='mpg',kind = 'ecdf')

# %%
sns.kdeplot(data = df, x = 'mpg')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.kdeplot(data = df, x = 'mpg', shade = 'True')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.rugplot(data = df, x = 'mpg')
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
sns.kdeplot(data = df, x = 'mpg', shade = 'True')
sns.rugplot(data = df, x = 'mpg')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
# agg안에 다양한 연산을 할 수 있다!
df["mpg"].agg(["skew", "kurt"])
# Out:
# skew    0.457066
# kurt   -0.510781
# Name: mpg, dtype: float64

# %%
sns.boxplot(data=df, x='mpg')
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
# boxplot의 각 선에 해당하는 값을 확인하고자 할 때, describe 를 가지고 확인해볼 수 있다!
df['mpg'].describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
sns.violinplot(data=df, x='mpg')
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data = df)
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(data = df)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.std()
# 결과를 보면, weight 값이 편차가 큼을 알 수 있다!
# Out:
# C:\ProgramData\Anaconda3\envs\goddol\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# mpg               7.815984
# cylinders         1.701004
# displacement    104.269838
# horsepower       38.491160
# weight          846.841774
# acceleration      2.757689
# model_year        3.697627
# dtype: float64

# %%
# scatterplot으로 수치데이터 시각화하기
sns.scatterplot(data = df, x='mpg', y = 'weight')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='weight'>

# %% [markdown]
# ## 회귀 시각화

# %%
sns.regplot(data = df, x='mpg', y='weight')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='weight'>

# %% [markdown]
# ## 잔차 시각화
#
#
# ### 회귀선의 잔차를 시각화 하기
#
# - residual : 잔차(오차)

# %%
sns.residplot(data = df, x = 'mpg', y = 'weight')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='weight'>

# %%
# lmplot 을 통해 범주값에 따라 색상, 서브플롯 그리기
# hue -> 색상을 입력하게 됨!
# col -> columns 에 따라 그래프 나누기! 

sns.lmplot(data = df, x = 'mpg', y='weight', hue = 'origin', col = 'origin')

# %% [markdown]
# ## jointplot으로 2개의 수치변수 표현하기

# %%
sns.jointplot(data = df, x='mpg', y='weight')

# %%
# kind 기본값이 scatterplot 임! 

sns.jointplot(data = df, x='mpg', y='weight',kind = 'hex')

# %% [markdown]
# ## Pairplot
#
# - 모든 수치 데이터에 대해 그래프를 그려줌!
# - pairplot은 시간이 오래걸리기 때문에 샘플을 추출해서 그려보자(100개)
# - 샘플의 수를 늘려가며 그리는 걸 추천!

# %%
df_sample = df.sample(100)
df_sample.head()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 76   18.0          4         121.0       112.0    2933          14.5
# 380  36.0          4         120.0        88.0    2160          14.5
# 3    16.0          8         304.0       150.0    3433          12.0
# 314  26.4          4         140.0        88.0    2870          18.1
# 362  24.2          6         146.0       120.0    2930          13.8
#
#      model_year  origin               name
# 76           72  europe    volvo 145e (sw)
# 380          82   japan   nissan stanza xe
# 3            70     usa      amc rebel sst
# 314          80     usa      ford fairmont
# 362          81   japan  datsun 810 maxima

# %%
sns.pairplot(data = df_sample)

# %%
# origin 값에 따라 다른 색상으로 그리기

sns.pairplot(data = df_sample, hue = 'origin')

# %%
sns.lineplot(data = df, x = 'model_year', y = 'mpg')
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='mpg'>

# %% [markdown]
# - 그림자는 신뢰구간을 의미!
# - y 축의 값은, mpg의 평균값을 의미!

# %%
sns.lineplot(data = df, x = 'model_year', y = 'mpg', ci =None)
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='mpg'>

# %% [markdown]
# - 신뢰구간을 사라지게 하려면 'ci=None' 을 입력하면 된다!

# %%
sns.relplot(data = df, x = 'model_year', y = 'mpg', ci =None)

# %%
sns.relplot(data = df, x = 'model_year', y = 'mpg', ci =None, col = 'origin', kind = 'line',hue = 'origin')

# %%
# 전체 수치 변수에 대한 시각화
sns.relplot(data = df)
